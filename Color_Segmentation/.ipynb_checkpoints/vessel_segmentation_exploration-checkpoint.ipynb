# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Get The Data

# %%
# We are going to grab one of the left crop images 
# that we extracting using left_right_top_crop.ipynb
im_path = "/home/andrew/Github/neuralink-bot/image_manipulation/left_crop/left_crop_0.jpg"

# %%
image = open_image(im_path)

# %%
image
# Out:
# Image (3, 466, 955)

# %% [markdown]
# # Extract Vessels From Images
