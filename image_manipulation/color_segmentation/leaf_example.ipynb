# %%
import sys
print(sys.path)
sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')
# Out:
# ['/home/andrew/Github/neuralink-bot/image_manipulation/color_segmentation', '', '/opt/ros/kinetic/lib/python2.7/dist-packages', '/home/andrew/anaconda3/lib/python37.zip', '/home/andrew/anaconda3/lib/python3.7', '/home/andrew/anaconda3/lib/python3.7/lib-dynload', '/home/andrew/anaconda3/lib/python3.7/site-packages', '/home/andrew/anaconda3/lib/python3.7/site-packages/IPython/extensions', '/home/andrew/.ipython']

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
leaf = cv2.imread('/home/andrew/Github/neuralink-bot/image_manipulation/color_segmentation/leaf.jpeg')
plt.imshow(leaf)
plt.show()

# %%
## getting green HSV color representation
green = np.uint8([[[0, 255, 0 ]]])
green_hsv = cv2.cvtColor(green,cv2.COLOR_BGR2HSV)
print(green_hsv)
# Out:
# [[[ 60 255 255]]]

# %%
green_low = np.array([45 , 100, 50] )
green_high = np.array([75, 255, 255])
curr_mask = cv2.inRange(hsv_leaf, green_low, green_high)
hsv_leaf[curr_mask > 0] = ([75,255,200])

# View the HSV Image
plt.imshow(hsv_leaf)
plt.show()

# %%
RGB_again = cv2.cvtColor(hsv_leaf, cv2.COLOR_HSV2RGB)
gray = cv2.cvtColor(RGB_again, cv2.COLOR_RGB2GRAY)

plt.imshow(gray)
plt.show()

# %%
ret, threshold = cv2.threshold(gray, 90, 255, 0)

plt.imshow(threshold)
plt.show()
